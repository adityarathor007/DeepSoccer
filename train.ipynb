# %%
import supervision as sv
from ultralytics import YOLO
from tqdm.notebook import tqdm 
import numpy as np
import itertools
from IPython.display import Image

# %%
# !yolo task=detect mode=train model=pretrained_models/yolov11n.pt data=dataset/roboflow/data.yaml batch=6 epochs=100 imgsz=1280 plots=True

# %%
# !yolo detect train model=pretrained_models/yolov11x.pt data=dataset/roboflow/data.yaml epochs=100 imgsz=1280 plots=True save=True batch=6 optimizer=AdamW lr0=0.00001
# Out:
# Ultralytics 8.3.94 🚀 Python-3.8.20 torch-2.0.1+cu117 CUDA:0 (NVIDIA RTX A6000, 48677MiB)
# ...

# %% [markdown]
# # Ball Tracking

# %%
# !yolo detect train model=pretrained_models/yolov11l.pt data=dataset/roboflow_ball/data_copy.yaml epochs=100 imgsz=1280 plots=True save=True batch=6 optimizer=AdamW lr0=0.00001
# Out:
# Ultralytics 8.3.94 🚀 Python-3.8.20 torch-2.0.1+cu117 CUDA:0 (NVIDIA RTX A6000, 48677MiB)
# ...

# %%
# !yolo detect train model=pretrained_model/yolov11x.pt data=dataset/roboflow_ball/data_copy.yaml epochs=100 imgsz=1280 plots=True save=True batch=6 optimizer=AdamW lr0=0.00001
# Out:
# Ultralytics 8.3.94 🚀 Python-3.8.20 torch-2.0.1+cu117 CUDA:0 (NVIDIA RTX A6000, 48677MiB)
# ...

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /storage/aditya/Yolo

# %% [markdown]
# # Precise Pitch Landmark Detection

# %%
from IPython.display import Image

# %%
# !yolo task=pose mode=train model=pretrained_models/yolov11x-pose.pt data=dataset/roboflow_pitch/data.yaml batch=32 epochs=100 imgsz=640 mosaic=0.0 plots=True patience=30

# %%
# !yolo task=pose mode=train model=pretrained_models/yolov11x-pose.pt data=dataset/roboflow_pitch/data.yaml batch=32 epochs=500 imgsz=640 mosaic=0.0 plots=True patience=30
# Out:
# Ultralytics 8.3.94 🚀 Python-3.8.20 torch-2.0.1+cu117 CUDA:0 (NVIDIA RTX A6000, 48677MiB)
# ...

# %%
# !yolo task=pose mode=train model=pretrained_models/yolov11x-pose.pt data=dataset/roboflow_pitch/data.yaml batch=16 epochs=500 imgsz=640 mosaic=0.0 plots=True
# Out:
# Ultralytics 8.3.94 🚀 Python-3.8.20 torch-2.0.1+cu117 CUDA:0 (NVIDIA RTX A6000, 48677MiB)
# ...

# %%
# !yolo task=pose mode=train model=pretrained_models/yolov8x-pose.pt data=dataset/roboflow_pitch/data.yaml batch=16 epochs=500 imgsz=640 mosaic=0.0 plots=True
# Out:
# Ultralytics 8.3.94 🚀 Python-3.8.20 torch-2.0.1+cu117 CUDA:0 (NVIDIA RTX A6000, 48677MiB)
# ...
